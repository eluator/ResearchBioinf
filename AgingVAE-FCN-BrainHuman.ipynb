# %%
import pandas as pd
import numpy as np
import pyreadr
import torch
from torch import nn
from torch.optim import Adam
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

# %%
data = pd.read_csv("./Data/Aging_data_combined_orthologs.csv")
datawNAN = data[data['Tissue'] == "Brain"][data['Species'] == "Human"].fillna(0)
datawNAN = torch.Tensor(datawNAN.select_dtypes(include=['float64']).iloc[:, :-1].values)
# Out:
# /tmp/ipykernel_5826/2326441598.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datawNAN = data[data['Tissue'] == "Brain"][data['Species'] == "Human"].fillna(0)

# %%
batch_size = 64

data_size = datawNAN.shape[0]
validation_split = .2
test_split = .2
split_val = int(np.floor(validation_split * data_size))
split_test = int(np.floor(test_split * data_size))

indices = list(range(data_size))
np.random.shuffle(indices)

train_indices, val_indices, test_indices = indices[split_val + split_test:], indices[:split_val], \
                                           indices[:split_val + split_test]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)
test_sampler = SubsetRandomSampler(test_indices)


train_loader = torch.utils.data.DataLoader(datawNAN, batch_size=batch_size,
                                           sampler=train_sampler)
val_loader = torch.utils.data.DataLoader(datawNAN, batch_size=batch_size,
                                          sampler=val_sampler)
test_loader = torch.utils.data.DataLoader(datawNAN, batch_size=batch_size,
                                           sampler=test_sampler)

# %%
class VaeEncoder(nn.Module):
    def __init__(self, input_size: int, latent_size: int, down_channels: int):
        super().__init__()
        self._latent_size = latent_size
        self._input_size = input_size

        in_features = input_size
        x = (input_size // (2 * latent_size)) ** (1 / down_channels)

        #         print(x, input_size, 2*latent_size, 1/down_channels)

        modules = []
        for _ in range(down_channels - 1):
            out_features = int(in_features // x)
            modules += [
                torch.nn.Linear(in_features, out_features, bias=True),
                torch.nn.BatchNorm1d(out_features),
                torch.nn.LeakyReLU()
            ]
            in_features = out_features
        modules += [torch.nn.Linear(in_features, 2 * latent_size)]
        self._encoder = nn.Sequential(*modules)
        # print(self._encoder.parameters())

    def forward(self, vector):
        encoded = self._encoder(vector)
        assert encoded.shape[1] == self._latent_size * 2
        mu, log_sigma = torch.split(encoded, self._latent_size, dim=1)
        return mu, log_sigma


class VaeDecoder(nn.Module):
    def __init__(self, output_size: int, latent_size: int, up_channels: int):
        super().__init__()
        self._latent_size = latent_size
        self._output_size = output_size

        in_features = latent_size
        x = (output_size // (latent_size)) ** (1 / up_channels)

        #         print(x)
        modules = []

        for _ in range(up_channels - 1):
            out_features = int(in_features * x)
            modules += [
                torch.nn.Linear(in_features, out_features, bias=True),
                torch.nn.BatchNorm1d(out_features),
                torch.nn.LeakyReLU()
            ]
            in_features = out_features
        modules += [torch.nn.Linear(in_features, output_size)]
        self._decoder = nn.Sequential(*modules)

    def forward(self, embeddings):
#         embeddings = embeddings.reshape(*embeddings.shape, 1, 1)
        return self._decoder(embeddings)

# %%
class Age(nn.Module):
    def __init__(self, input_size: int, l1_lambda : int, l2_lambda: int, hidden_size = 50):
        super().__init__()
        self._input_size = input_size

        self._model = nn.Sequential(torch.nn.Linear(input_size, hidden_size, bias=True),
                                    torch.nn.ReLU(),
                                    torch.nn.BatchNorm1d(hidden_size),
                                    torch.nn.Linear(hidden_size, 1, bias=True),
                                    torch.nn.ReLU(),
                                    torch.nn.BatchNorm1d(1))
        
        self.l1_lambda = l1_lambda
        self.l2_lambda = l2_lambda
        # print(self._encoder.parameters())

    def forward(self, vector):
        return self._model(vector).flatten()
    
    def l1_reg(self):
        l1_norm = sum([w.abs().sum() for w in self._model.parameters()])

        return self.l1_lambda * l1_norm

    def l2_reg(self):
        l2_norm = sum([w.pow(2).sum() for w in self._model.parameters()])
        
        return self.l2_lambda * l2_norm

# %%
class VAEAge(nn.Module):
    def __init__(self, input_size, l1_lambda : int, l2_lambda: int, latent_size=10, down_channels=2, up_channels=2):
        super().__init__()

        self._encoder = VaeEncoder(input_size, latent_size, down_channels)
        self._decoder = VaeDecoder(input_size, latent_size, up_channels)
        self._age = Age(latent_size, l1_lambda, l2_lambda)
        
    def forward(self, x):
        mu, log_sigma = self._encoder(x)
        sigma = torch.exp(log_sigma)

        kld = 0.5 * (sigma + torch.square(mu) - log_sigma - 1)

        z = mu + torch.randn_like(sigma) * sigma
        x_pred = self._decoder(z)
        age_pred = self._age(z)
        return x_pred, kld, age_pred

    def encode(self, x):
        mu, log_sigma = self._encoder(x)
        sigma = torch.exp(log_sigma)

        return mu + torch.randn_like(sigma) * sigma

    def decode(self, z):
        return self._decoder(z)
   
    def reg(self):
        return self._age.l1_reg() + self._age.l2_reg()

# %%
def train_vae(vae, dataloader, dataloader_val, dataset, batch_size):
    vae.cuda()

    epochs = 201
    vae_optim = Adam(vae.parameters(), lr=1e-4)

    #     test_imgs_1 = torch.cat([dataset[i].unsqueeze(0) for i in (0, 34, 76, 1509)])
    #     test_imgs_2 = torch.cat([dataset[i].unsqueeze(0) for i in (734, 123, 512, 3634)])

    for ep in range(epochs):
        total_batches = 0
        rec_loss_avg = 0
        kld_loss_avg = 0
        r2_avg = 0
        age_loss_avg = 0
        age_reg_avg = 0
        
        total_batches_val = 0
        rec_loss_avg_val = 0
        kld_loss_avg_val = 0
        r2_avg_val = 0
        age_loss_avg_val = 0
        
#                 if ep % 10 == 0:
#                     with torch.no_grad():
#                         indices = np.random.choice(dataset.shape[0], 10)
#                         z_1 = vae.encode(test_imgs_1.cuda())
#                         z_2 = vae.encode(test_imgs_2.cuda())
#                         x_int = []
#                         for i in range(9):
#                             z = (i * z_1 + (8 - i) * z_2) / 8
#                             x_int.append(vae.decode(z))
#                         x_int = torch.cat(x_int)
#                         visualise(x_int, rows=len(test_imgs_1))
#                         z_rand = torch.randn_like(z_1)
#                         x_int = vae.decode(z_rand)
#                         visualise(x_int, rows=len(test_imgs_1)//2)

        for i, batch in enumerate(dataloader):
            x, age = batch[:, :-1].cuda(), batch[:, -1].cuda()
            if len(batch) < batch_size:
                continue
            total_batches += 1
            x_rec, kld, age_pred = vae(x)
            img_elems = float(np.prod(list(batch.size())))
            kld_loss = kld.sum() / batch_size
            rec_loss = ((x_rec - x) ** 2).sum() / batch_size
            dis = ((x - torch.mean(x, dim = 0)) ** 2).sum() / batch_size
            r2 = 1 - rec_loss/dis
            age_loss = torch.sqrt(((age_pred - age) ** 2).sum() / len(age))
            if i == 0:
                print("age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape", age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape)
                print("age_pred[0], age[0], batch_size, age_loss", age_pred[0], age[0], batch_size, age_loss)
            age_reg = vae.reg()
            loss = rec_loss + 0.1 * kld_loss + 500 * (age_loss + age_reg) # https://openreview.net/forum?id=Sy2fzU9gl
            vae_optim.zero_grad()
            loss.backward()
            vae_optim.step()
            kld_loss_avg += kld_loss.item()
            rec_loss_avg += rec_loss.item()
            age_loss_avg += age_loss.item()
            age_reg_avg += age_reg.item()
            
            r2_avg += r2.item()


        print(
            f"Epoch {ep + 1} | Age loss: {age_loss_avg / total_batches} |Age reg: {age_reg_avg / total_batches} | MSE loss: {rec_loss_avg / total_batches} | R2: {r2_avg / total_batches} | KLD loss: {kld_loss_avg / total_batches}")
        
        
        with torch.no_grad():
            for i, batch in enumerate(dataloader_val):
                x, age = batch[:, :-1].cuda(), batch[:, -1].cuda()
                if len(batch) < batch_size:
                    continue
                total_batches_val += 1
                x_rec, kld, age_pred = vae(x)
                kld_loss = kld.sum() / batch_size
                rec_loss = ((x_rec - x) ** 2).sum() / batch_size
                dis = ((x - torch.mean(x, dim = 0)) ** 2).sum() / batch_size
                age_loss = torch.sqrt(((age_pred - age) ** 2).sum() / len(age))
                r2 = 1 - rec_loss/dis
                r2_avg_val += r2.item()
                kld_loss_avg_val += kld_loss.item()
                rec_loss_avg_val += rec_loss.item()
                age_loss_avg_val += age_loss.item()

        print(
            f"Epoch {ep + 1} | Age loss val: {age_loss_avg_val / total_batches_val} | MSE loss val: {rec_loss_avg_val / total_batches_val} | R2 val: {r2_avg_val / total_batches_val} | KLD loss val: {kld_loss_avg_val / total_batches_val}")
l1_lambda, l2_lambda = 0.03, 0.01
input_size = datawNAN.shape[1] - 1
vae = VAEAge(input_size, l1_lambda, l2_lambda)
train_vae(vae, train_loader, val_loader, datawNAN, batch_size)
# Out:
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5361, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1745, device='cuda:0') 64 tensor(1.1170, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 1 | Age loss: 1.081804672876994 |Age reg: 4.997391064961751 | MSE loss: 18487.838324652777 | R2: -6.586537520090739 | KLD loss: 25.82974253760444
# Epoch 1 | Age loss val: 1.0993591944376628 | MSE loss val: 16743.681640625 | R2 val: -5.798830668131511 | KLD loss val: 4.983753522237142
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.0390, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5153, device='cuda:0') 64 tensor(1.0587, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 2 | Age loss: 1.0740655660629272 |Age reg: 4.979015138414171 | MSE loss: 15728.085611979166 | R2: -5.670222918192546 | KLD loss: 5.288536018795437
# Epoch 2 | Age loss val: 1.071709116299947 | MSE loss val: 14210.152018229166 | R2 val: -4.762178421020508 | KLD loss val: 5.084299564361572
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4335, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5153, device='cuda:0') 64 tensor(1.0887, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 3 | Age loss: 1.0639024045732286 |Age reg: 4.960660563574897 | MSE loss: 13317.677083333334 | R2: -4.695403496424357 | KLD loss: 5.640423085954454
# Epoch 3 | Age loss val: 1.0493885676066081 | MSE loss val: 12032.4853515625 | R2 val: -3.6998753547668457 | KLD loss val: 6.077095031738281
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(2.8890, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7978, device='cuda:0') 64 tensor(1.0159, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 4 | Age loss: 1.0502749416563246 |Age reg: 4.942353990342882 | MSE loss: 11298.718424479166 | R2: -3.6390591727362738 | KLD loss: 6.966791046990289
# Epoch 4 | Age loss val: 1.0439834992090862 | MSE loss val: 10137.185872395834 | R2 val: -3.115228255589803 | KLD loss val: 7.897019227345784
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4733, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4405, device='cuda:0') 64 tensor(1.0223, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 5 | Age loss: 1.0327320496241252 |Age reg: 4.9241772757636175 | MSE loss: 9517.375108506945 | R2: -2.9477025667826333 | KLD loss: 8.819824430677626
# Epoch 5 | Age loss val: 1.049567421277364 | MSE loss val: 8613.8896484375 | R2 val: -2.8614583015441895 | KLD loss val: 10.673452695210775
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4727, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7563, device='cuda:0') 64 tensor(1.0670, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 6 | Age loss: 1.0309634274906583 |Age reg: 4.9059846136305065 | MSE loss: 7994.058376736111 | R2: -2.298067490259806 | KLD loss: 11.929520924886068
# Epoch 6 | Age loss val: 1.0298041899998982 | MSE loss val: 7176.447916666667 | R2 val: -1.8211339314778645 | KLD loss val: 13.964670499165853
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4773, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2078, device='cuda:0') 64 tensor(0.9984, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 7 | Age loss: 1.0219871070649889 |Age reg: 4.887758096059163 | MSE loss: 6592.833279079861 | R2: -1.7141645616955228 | KLD loss: 15.884853574964735
# Epoch 7 | Age loss val: 1.036603609720866 | MSE loss val: 5860.508951822917 | R2 val: -1.3780811627705891 | KLD loss val: 18.225387573242188
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4805, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6067, device='cuda:0') 64 tensor(1.0548, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 8 | Age loss: 1.0230647457970514 |Age reg: 4.8695863087972 | MSE loss: 5512.067491319444 | R2: -1.1819138262006972 | KLD loss: 20.026073455810547
# Epoch 8 | Age loss val: 1.042660395304362 | MSE loss val: 4974.314615885417 | R2 val: -1.0875988006591797 | KLD loss val: 21.98187255859375
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4107, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4405, device='cuda:0') 64 tensor(1.0293, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 9 | Age loss: 1.0215786894162495 |Age reg: 4.851506816016303 | MSE loss: 4587.976671006944 | R2: -0.8692532115512424 | KLD loss: 23.57261021931966
# Epoch 9 | Age loss val: 1.0344254970550537 | MSE loss val: 4209.7763671875 | R2 val: -0.6597574154535929 | KLD loss val: 24.960416793823242
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.4353, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6482, device='cuda:0') 64 tensor(1.0022, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 10 | Age loss: 1.025075422392951 |Age reg: 4.833554320865208 | MSE loss: 3903.9439832899307 | R2: -0.6179979509777493 | KLD loss: 26.54405869377984
# Epoch 10 | Age loss val: 1.0200427969296773 | MSE loss val: 3640.0224609375 | R2 val: -0.45936334133148193 | KLD loss val: 27.684789021809895
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4423, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4986, device='cuda:0') 64 tensor(1.0140, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 11 | Age loss: 1.0166415439711676 |Age reg: 4.8158045874701605 | MSE loss: 3459.4562174479165 | R2: -0.4266624053319295 | KLD loss: 28.854757732815212
# Epoch 11 | Age loss val: 1.029223124186198 | MSE loss val: 3189.9173990885415 | R2 val: -0.31247711181640625 | KLD loss val: 29.58288828531901
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4045, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6067, device='cuda:0') 64 tensor(1.0057, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 12 | Age loss: 1.0041717290878296 |Age reg: 4.798171679178874 | MSE loss: 2943.9314778645835 | R2: -0.24333210123909843 | KLD loss: 30.688095092773438
# Epoch 12 | Age loss val: 1.0258450309435527 | MSE loss val: 2965.4639485677085 | R2 val: -0.17183450857798258 | KLD loss val: 31.091875076293945
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.0851, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7396, device='cuda:0') 64 tensor(1.0218, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 13 | Age loss: 0.9911798569891188 |Age reg: 4.780649185180664 | MSE loss: 2685.052191840278 | R2: -0.057695104016198054 | KLD loss: 31.98417027791341
# Epoch 13 | Age loss val: 1.000203291575114 | MSE loss val: 2575.2379557291665 | R2 val: -0.056505719820658364 | KLD loss val: 32.48916753133138
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5130, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4405, device='cuda:0') 64 tensor(0.9882, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 14 | Age loss: 0.9812290800942315 |Age reg: 4.763207329644097 | MSE loss: 2407.488023546007 | R2: -0.0009515682856241862 | KLD loss: 33.712395350138344
# Epoch 14 | Age loss val: 1.0151345531145732 | MSE loss val: 2531.0992024739585 | R2 val: -0.028768996397654217 | KLD loss val: 33.78661219278971
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.3983, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3740, device='cuda:0') 64 tensor(0.9827, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 15 | Age loss: 0.9740406274795532 |Age reg: 4.745885372161865 | MSE loss: 2183.8947482638887 | R2: 0.12229836649364895 | KLD loss: 34.74675369262695
# Epoch 15 | Age loss val: 0.9999505082766215 | MSE loss val: 2394.967529296875 | R2 val: 0.05927896499633789 | KLD loss val: 34.747920989990234
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5431, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3740, device='cuda:0') 64 tensor(0.9666, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 16 | Age loss: 0.9607021080123054 |Age reg: 4.728656768798828 | MSE loss: 2016.705078125 | R2: 0.19034290975994533 | KLD loss: 35.68402099609375
# Epoch 16 | Age loss val: 0.9900199969609579 | MSE loss val: 1893.9144694010417 | R2 val: 0.22412806749343872 | KLD loss val: 35.77730941772461
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5276, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1579, device='cuda:0') 64 tensor(0.9832, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 17 | Age loss: 0.9683251976966858 |Age reg: 4.711558394961887 | MSE loss: 1775.3708089192708 | R2: 0.28959665033552384 | KLD loss: 36.61264080471463
# Epoch 17 | Age loss val: 0.9917329549789429 | MSE loss val: 1943.374755859375 | R2 val: 0.2234803040822347 | KLD loss val: 36.3193105061849
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5407, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3158, device='cuda:0') 64 tensor(0.9910, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 18 | Age loss: 0.9622940553559197 |Age reg: 4.69460556242201 | MSE loss: 1733.9991997612847 | R2: 0.29869654443528915 | KLD loss: 37.75918621487088
# Epoch 18 | Age loss val: 1.0012345910072327 | MSE loss val: 1806.1615804036458 | R2 val: 0.2921183904012044 | KLD loss val: 37.53452936808268
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4889, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4571, device='cuda:0') 64 tensor(0.9640, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 19 | Age loss: 0.9573163853751289 |Age reg: 4.6777364942762585 | MSE loss: 1711.9495307074653 | R2: 0.32331148121092057 | KLD loss: 38.13136333889432
# Epoch 19 | Age loss val: 0.9867310523986816 | MSE loss val: 1848.2091064453125 | R2 val: 0.19860597451527914 | KLD loss val: 37.95985794067383
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.9281, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7646, device='cuda:0') 64 tensor(0.9826, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 20 | Age loss: 0.9507064157062106 |Age reg: 4.660882314046224 | MSE loss: 1581.557861328125 | R2: 0.3647421399752299 | KLD loss: 38.845286475287544
# Epoch 20 | Age loss val: 0.9732478062311808 | MSE loss val: 1574.5826416015625 | R2 val: 0.3638468186060588 | KLD loss val: 38.81383768717448
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.1619, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5568, device='cuda:0') 64 tensor(0.9264, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 21 | Age loss: 0.9445001350508796 |Age reg: 4.6440743870205345 | MSE loss: 1417.0005967881943 | R2: 0.42780905299716526 | KLD loss: 39.13767454359267
# Epoch 21 | Age loss val: 0.9768364429473877 | MSE loss val: 1683.4088134765625 | R2 val: 0.3398614724477132 | KLD loss val: 38.55046081542969
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6006, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1579, device='cuda:0') 64 tensor(0.9231, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 22 | Age loss: 0.9358071552382575 |Age reg: 4.627342171139187 | MSE loss: 1507.0069580078125 | R2: 0.38172242376539445 | KLD loss: 39.45404561360677
# Epoch 22 | Age loss val: 0.9715932210286459 | MSE loss val: 1580.9081624348958 | R2 val: 0.38177939256032306 | KLD loss val: 39.12730407714844
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.0470, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7064, device='cuda:0') 64 tensor(0.9250, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 23 | Age loss: 0.9386650853686862 |Age reg: 4.610658645629883 | MSE loss: 1477.3792453342014 | R2: 0.41661808888117474 | KLD loss: 39.671024322509766
# Epoch 23 | Age loss val: 0.9749626715977987 | MSE loss val: 1569.6426595052083 | R2 val: 0.3916545510292053 | KLD loss val: 39.851298014322914
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6094, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3989, device='cuda:0') 64 tensor(0.9782, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 24 | Age loss: 0.93563754691018 |Age reg: 4.594080872005886 | MSE loss: 1592.426513671875 | R2: 0.35669740703370834 | KLD loss: 39.75419192843967
# Epoch 24 | Age loss val: 0.9620535771052042 | MSE loss val: 1784.6868082682292 | R2 val: 0.28426549832026166 | KLD loss val: 39.19133504231771
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4824, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2244, device='cuda:0') 64 tensor(0.9754, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 25 | Age loss: 0.9308392935329013 |Age reg: 4.577557192908393 | MSE loss: 1646.7223714192708 | R2: 0.34779394335216945 | KLD loss: 39.08120981852213
# Epoch 25 | Age loss val: 0.9625053604443868 | MSE loss val: 1507.3821614583333 | R2 val: 0.4079204797744751 | KLD loss val: 39.022169748942055
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5470, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.0083, device='cuda:0') 64 tensor(0.9081, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 26 | Age loss: 0.9242882794804044 |Age reg: 4.561079925960964 | MSE loss: 1300.0146145290798 | R2: 0.45615871747334796 | KLD loss: 39.44287999471029
# Epoch 26 | Age loss val: 0.9605570634206136 | MSE loss val: 2045.5153401692708 | R2 val: 0.12744816144307455 | KLD loss val: 37.97799173990885
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.1965, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7313, device='cuda:0') 64 tensor(0.9575, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 27 | Age loss: 0.9252566827668084 |Age reg: 4.544624434577094 | MSE loss: 1348.9236450195312 | R2: 0.44926584429211086 | KLD loss: 39.005435943603516
# Epoch 27 | Age loss val: 0.9708536863327026 | MSE loss val: 1421.9142659505208 | R2 val: 0.4509105086326599 | KLD loss val: 38.82412974039713
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4987, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5734, device='cuda:0') 64 tensor(0.9174, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 28 | Age loss: 0.9143771727879842 |Age reg: 4.528233740064833 | MSE loss: 1294.7527737087673 | R2: 0.4521695441669888 | KLD loss: 39.6069704691569
# Epoch 28 | Age loss val: 0.9539259870847067 | MSE loss val: 1522.1209309895833 | R2 val: 0.3968803286552429 | KLD loss val: 38.7303466796875
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6011, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1579, device='cuda:0') 64 tensor(0.9422, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 29 | Age loss: 0.9237693217065599 |Age reg: 4.511844846937391 | MSE loss: 1249.199239095052 | R2: 0.5019629531436496 | KLD loss: 39.251043531629776
# Epoch 29 | Age loss val: 0.9565197030703226 | MSE loss val: 1600.9998372395833 | R2 val: 0.3580886125564575 | KLD loss val: 39.493726094563804
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5918, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2327, device='cuda:0') 64 tensor(0.8954, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 30 | Age loss: 0.9194856815867953 |Age reg: 4.495533837212457 | MSE loss: 1409.1966484917534 | R2: 0.41183673673205906 | KLD loss: 40.01952446831597
# Epoch 30 | Age loss val: 0.9569035569826762 | MSE loss val: 1423.5923665364583 | R2 val: 0.4348340630531311 | KLD loss val: 39.43689219156901
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.9507, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6698, device='cuda:0') 64 tensor(0.9263, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 31 | Age loss: 0.9246973726484511 |Age reg: 4.479292816585964 | MSE loss: 1493.6659071180557 | R2: 0.40376603603363037 | KLD loss: 38.89619233873155
# Epoch 31 | Age loss val: 0.9497935573259989 | MSE loss val: 1473.3705240885417 | R2 val: 0.3771612246831258 | KLD loss val: 39.62195332845052
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6498, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1496, device='cuda:0') 64 tensor(0.9256, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 32 | Age loss: 0.9106886784235636 |Age reg: 4.463249047597249 | MSE loss: 1325.5167100694443 | R2: 0.45281362533569336 | KLD loss: 38.75654559665256
# Epoch 32 | Age loss val: 0.948492169380188 | MSE loss val: 1450.706787109375 | R2 val: 0.42214783032735187 | KLD loss val: 38.24989573160807
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6627, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1579, device='cuda:0') 64 tensor(0.9302, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 33 | Age loss: 0.9095825685395135 |Age reg: 4.447213755713569 | MSE loss: 1360.5051676432292 | R2: 0.44460613197750515 | KLD loss: 38.355867597791885
# Epoch 33 | Age loss val: 0.9446354707082113 | MSE loss val: 1380.38671875 | R2 val: 0.46076258023579914 | KLD loss val: 38.217769622802734
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.1146, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7396, device='cuda:0') 64 tensor(0.9406, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 34 | Age loss: 0.9056027928988138 |Age reg: 4.4312262535095215 | MSE loss: 1063.794969346788 | R2: 0.5641246967845492 | KLD loss: 38.24869579739041
# Epoch 34 | Age loss val: 0.9455928603808085 | MSE loss val: 1282.5944417317708 | R2 val: 0.48018836975097656 | KLD loss val: 38.20634969075521
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.5962, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7480, device='cuda:0') 64 tensor(0.8866, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 35 | Age loss: 0.9061097105344137 |Age reg: 4.415227307213677 | MSE loss: 1212.730461968316 | R2: 0.5078517132335238 | KLD loss: 38.684360080295136
# Epoch 35 | Age loss val: 0.9439161419868469 | MSE loss val: 1506.8097330729167 | R2 val: 0.4042038917541504 | KLD loss val: 38.38840993245443
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6285, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3740, device='cuda:0') 64 tensor(0.9065, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 36 | Age loss: 0.9005852672788832 |Age reg: 4.399247010548909 | MSE loss: 1052.5844048394097 | R2: 0.5729596747292413 | KLD loss: 38.86358345879449
# Epoch 36 | Age loss val: 0.94670436779658 | MSE loss val: 1238.4831136067708 | R2 val: 0.4749092260996501 | KLD loss val: 39.19764963785807
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6050, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5568, device='cuda:0') 64 tensor(0.8840, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 37 | Age loss: 0.8983475698365105 |Age reg: 4.383315616183811 | MSE loss: 1080.0418904622395 | R2: 0.5626762906710306 | KLD loss: 39.04475360446506
# Epoch 37 | Age loss val: 0.9465729395548502 | MSE loss val: 1253.5926513671875 | R2 val: 0.493660847345988 | KLD loss val: 39.42491149902344
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6014, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1579, device='cuda:0') 64 tensor(0.8956, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 38 | Age loss: 0.9009139074219598 |Age reg: 4.367464171515571 | MSE loss: 1196.2035997178818 | R2: 0.516669385963016 | KLD loss: 39.14565192328559
# Epoch 38 | Age loss val: 0.9358892838160197 | MSE loss val: 1217.723876953125 | R2 val: 0.514661987622579 | KLD loss val: 39.33550262451172
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.5649, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3740, device='cuda:0') 64 tensor(0.9002, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 39 | Age loss: 0.8983307878176371 |Age reg: 4.35170931286282 | MSE loss: 1159.5665622287327 | R2: 0.5196063849661086 | KLD loss: 38.877774980333115
# Epoch 39 | Age loss val: 0.9366168777147929 | MSE loss val: 1519.1568196614583 | R2 val: 0.337912658850352 | KLD loss val: 39.36640421549479
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6307, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4321, device='cuda:0') 64 tensor(0.8922, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 40 | Age loss: 0.9020206332206726 |Age reg: 4.3360365231831866 | MSE loss: 1234.0524156358506 | R2: 0.4974580605824788 | KLD loss: 38.78969362046983
# Epoch 40 | Age loss val: 0.9313491582870483 | MSE loss val: 1274.0915934244792 | R2 val: 0.4980180064837138 | KLD loss val: 38.60056813557943
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5256, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1828, device='cuda:0') 64 tensor(0.9142, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 41 | Age loss: 0.8920620613627963 |Age reg: 4.320338832007514 | MSE loss: 1214.7553032769097 | R2: 0.4925777249866062 | KLD loss: 38.210178799099396
# Epoch 41 | Age loss val: 0.9408892393112183 | MSE loss val: 1159.690185546875 | R2 val: 0.5132647156715393 | KLD loss val: 38.64098612467448
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.8128, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6316, device='cuda:0') 64 tensor(0.8883, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 42 | Age loss: 0.8951109184159173 |Age reg: 4.304699209001329 | MSE loss: 1090.968065049913 | R2: 0.568129214975569 | KLD loss: 37.89291636149088
# Epoch 42 | Age loss val: 0.9287562568982443 | MSE loss val: 1186.2522379557292 | R2 val: 0.5180211067199707 | KLD loss val: 38.31166330973307
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6265, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.0166, device='cuda:0') 64 tensor(0.9137, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 43 | Age loss: 0.8948197099897597 |Age reg: 4.289161470201281 | MSE loss: 1066.5926038953994 | R2: 0.5667619440290663 | KLD loss: 38.24006144205729
# Epoch 43 | Age loss val: 0.9378975033760071 | MSE loss val: 1208.450927734375 | R2 val: 0.5340067545572916 | KLD loss val: 38.272961934407554
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.1369, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6316, device='cuda:0') 64 tensor(0.8740, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 44 | Age loss: 0.8896601133876376 |Age reg: 4.273606830173069 | MSE loss: 1127.2156575520833 | R2: 0.5526847574445937 | KLD loss: 38.07518641153971
# Epoch 44 | Age loss val: 0.9302181800206503 | MSE loss val: 1246.9650472005208 | R2 val: 0.48499252398808795 | KLD loss val: 38.37706629435221
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.0156, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5984, device='cuda:0') 64 tensor(0.9172, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 45 | Age loss: 0.8920324179861281 |Age reg: 4.258067978752984 | MSE loss: 1090.868943956163 | R2: 0.5702922940254211 | KLD loss: 38.1214230855306
# Epoch 45 | Age loss val: 0.9315360188484192 | MSE loss val: 1205.2574055989583 | R2 val: 0.5238940318425497 | KLD loss val: 38.40485382080078
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.5270, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7812, device='cuda:0') 64 tensor(0.8804, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 46 | Age loss: 0.8873286777072482 |Age reg: 4.2426562839084205 | MSE loss: 1010.1294894748264 | R2: 0.5832865701781379 | KLD loss: 38.98681894938151
# Epoch 46 | Age loss val: 0.9196528792381287 | MSE loss val: 1165.1032307942708 | R2 val: 0.5464235146840414 | KLD loss val: 38.74163564046224
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.9135, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6316, device='cuda:0') 64 tensor(0.8713, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 47 | Age loss: 0.8854939606454637 |Age reg: 4.227167235480414 | MSE loss: 1016.870849609375 | R2: 0.5819531083106995 | KLD loss: 38.849493662516274
# Epoch 47 | Age loss val: 0.9359355966250101 | MSE loss val: 1187.0193277994792 | R2 val: 0.5225230654080709 | KLD loss val: 39.12507120768229
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.1330, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7230, device='cuda:0') 64 tensor(0.9049, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 48 | Age loss: 0.8852779799037509 |Age reg: 4.211725499894884 | MSE loss: 1053.4761081271702 | R2: 0.5727926161554124 | KLD loss: 38.6399892171224
# Epoch 48 | Age loss val: 0.9341206351915995 | MSE loss val: 1207.1642659505208 | R2 val: 0.49880093336105347 | KLD loss val: 38.97573725382487
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.7063, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5319, device='cuda:0') 64 tensor(0.8673, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 49 | Age loss: 0.8788754012849596 |Age reg: 4.196303897433811 | MSE loss: 994.7256130642361 | R2: 0.606561005115509 | KLD loss: 38.352650536431206
# Epoch 49 | Age loss val: 0.9257695476214091 | MSE loss val: 1427.2667236328125 | R2 val: 0.42416268587112427 | KLD loss val: 38.6436767578125
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6363, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2161, device='cuda:0') 64 tensor(0.8742, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 50 | Age loss: 0.8836296796798706 |Age reg: 4.1809067196316185 | MSE loss: 919.3477240668403 | R2: 0.634178982840644 | KLD loss: 38.56642193264432
# Epoch 50 | Age loss val: 0.9201977054278055 | MSE loss val: 1091.108662923177 | R2 val: 0.5567131241162618 | KLD loss val: 39.233784993489586
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5992, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1330, device='cuda:0') 64 tensor(0.8725, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 51 | Age loss: 0.8730569415622287 |Age reg: 4.165553251902263 | MSE loss: 922.3302951388889 | R2: 0.6296131213506063 | KLD loss: 38.43182881673177
# Epoch 51 | Age loss val: 0.9154591759045919 | MSE loss val: 1285.6697998046875 | R2 val: 0.49805543820063275 | KLD loss val: 38.39005915323893
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.4226, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1662, device='cuda:0') 64 tensor(0.8532, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 52 | Age loss: 0.8751011225912306 |Age reg: 4.150203969743517 | MSE loss: 1063.1085679796006 | R2: 0.5559752914640639 | KLD loss: 38.49938413831923
# Epoch 52 | Age loss val: 0.9254515767097473 | MSE loss val: 1125.998046875 | R2 val: 0.5417294104894003 | KLD loss val: 39.03240712483724
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5968, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.0083, device='cuda:0') 64 tensor(0.9117, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 53 | Age loss: 0.8795510000652738 |Age reg: 4.13490613301595 | MSE loss: 923.9294908311632 | R2: 0.631484223736657 | KLD loss: 38.80270767211914
# Epoch 53 | Age loss val: 0.9149853189786276 | MSE loss val: 1101.3947347005208 | R2 val: 0.5545874238014221 | KLD loss val: 39.44326146443685
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(2.6334, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7396, device='cuda:0') 64 tensor(0.9251, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 54 | Age loss: 0.8715490102767944 |Age reg: 4.119715160793728 | MSE loss: 938.0921291775173 | R2: 0.6184203955862257 | KLD loss: 38.88102595011393
# Epoch 54 | Age loss val: 0.9177415569623312 | MSE loss val: 1188.8664143880208 | R2 val: 0.51006547609965 | KLD loss val: 38.88921101888021
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5345, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2078, device='cuda:0') 64 tensor(0.8595, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 55 | Age loss: 0.8706434832678901 |Age reg: 4.104525619082981 | MSE loss: 1011.8407796223959 | R2: 0.5927858352661133 | KLD loss: 38.36769570244683
# Epoch 55 | Age loss val: 0.9131641189257304 | MSE loss val: 1145.3129069010417 | R2 val: 0.5439223448435465 | KLD loss val: 38.25857798258463
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5653, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1247, device='cuda:0') 64 tensor(0.8591, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 56 | Age loss: 0.8705643945270114 |Age reg: 4.08933687210083 | MSE loss: 974.5587293836805 | R2: 0.6126246452331543 | KLD loss: 38.05480533175998
# Epoch 56 | Age loss val: 0.9214582045873007 | MSE loss val: 1054.844970703125 | R2 val: 0.572797973950704 | KLD loss val: 38.77666982014974
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5421, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1413, device='cuda:0') 64 tensor(0.8660, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 57 | Age loss: 0.8735238181220161 |Age reg: 4.074168523152669 | MSE loss: 945.9090983072916 | R2: 0.6181428962283664 | KLD loss: 38.49140421549479
# Epoch 57 | Age loss val: 0.9201377232869467 | MSE loss val: 1172.9192301432292 | R2 val: 0.533352772394816 | KLD loss val: 38.17579142252604
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.7006, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2161, device='cuda:0') 64 tensor(0.8543, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 58 | Age loss: 0.8746786581145393 |Age reg: 4.059178352355957 | MSE loss: 942.5009765625 | R2: 0.615419500403934 | KLD loss: 38.249165852864586
# Epoch 58 | Age loss val: 0.904841959476471 | MSE loss val: 1106.4957275390625 | R2 val: 0.5436077912648519 | KLD loss val: 38.34511947631836
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.6619, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3906, device='cuda:0') 64 tensor(0.8633, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 59 | Age loss: 0.8704459004931979 |Age reg: 4.044240050845676 | MSE loss: 989.2777099609375 | R2: 0.5976624488830566 | KLD loss: 37.85530302259657
# Epoch 59 | Age loss val: 0.9074122111002604 | MSE loss val: 1050.0159912109375 | R2 val: 0.582570473353068 | KLD loss val: 38.25082143147787
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.0380, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6067, device='cuda:0') 64 tensor(0.9026, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 60 | Age loss: 0.8709413078096178 |Age reg: 4.0293139881557885 | MSE loss: 938.0788235134548 | R2: 0.6352080901463827 | KLD loss: 37.57158957587348
# Epoch 60 | Age loss val: 0.9133397738138834 | MSE loss val: 1046.0118815104167 | R2 val: 0.5705465078353882 | KLD loss val: 38.020528157552086
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.5312, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3158, device='cuda:0') 64 tensor(0.8201, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 61 | Age loss: 0.8677131864759657 |Age reg: 4.014420244428846 | MSE loss: 918.7344563802084 | R2: 0.6323797835244073 | KLD loss: 37.153128729926216
# Epoch 61 | Age loss val: 0.9107959071795145 | MSE loss val: 1028.7964680989583 | R2 val: 0.5822727680206299 | KLD loss val: 37.94005457560221
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.7953, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5817, device='cuda:0') 64 tensor(0.8805, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 62 | Age loss: 0.870281868510776 |Age reg: 3.9995563560061984 | MSE loss: 894.8804456922743 | R2: 0.627506415049235 | KLD loss: 37.467105865478516
# Epoch 62 | Age loss val: 0.9069200754165649 | MSE loss val: 1002.0753173828125 | R2 val: 0.6084876855214437 | KLD loss val: 37.2157096862793
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6137, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1828, device='cuda:0') 64 tensor(0.8457, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 63 | Age loss: 0.8624585999382867 |Age reg: 3.9847801791297064 | MSE loss: 842.253919813368 | R2: 0.6637642780939738 | KLD loss: 37.435530768500435
# Epoch 63 | Age loss val: 0.9113476276397705 | MSE loss val: 974.5486653645834 | R2 val: 0.5987253189086914 | KLD loss val: 37.63634490966797
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5845, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1163, device='cuda:0') 64 tensor(0.8693, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 64 | Age loss: 0.8607611126369901 |Age reg: 3.969969246122572 | MSE loss: 838.5312974717882 | R2: 0.6691918836699592 | KLD loss: 37.38999938964844
# Epoch 64 | Age loss val: 0.9076585372289022 | MSE loss val: 1019.7493082682291 | R2 val: 0.5876760482788086 | KLD loss val: 38.31148783365885
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.2195, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7646, device='cuda:0') 64 tensor(0.8674, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 65 | Age loss: 0.8622445397906833 |Age reg: 3.9551895459493003 | MSE loss: 854.8385416666666 | R2: 0.6580544379022386 | KLD loss: 38.024681091308594
# Epoch 65 | Age loss val: 0.9046589533487955 | MSE loss val: 971.5157674153646 | R2 val: 0.606066107749939 | KLD loss val: 38.31818771362305
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5963, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4405, device='cuda:0') 64 tensor(0.8741, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 66 | Age loss: 0.8582289748721652 |Age reg: 3.9404005209604898 | MSE loss: 842.6022135416666 | R2: 0.6569651365280151 | KLD loss: 37.9736696879069
# Epoch 66 | Age loss val: 0.9028217991193136 | MSE loss val: 942.2982788085938 | R2 val: 0.5842800935109457 | KLD loss val: 39.036705017089844
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.0077, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4571, device='cuda:0') 64 tensor(0.8759, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 67 | Age loss: 0.8576798637708029 |Age reg: 3.9256762663523355 | MSE loss: 824.8839721679688 | R2: 0.6689979963832431 | KLD loss: 38.00035688612196
# Epoch 67 | Age loss val: 0.8945403695106506 | MSE loss val: 908.1031290690104 | R2 val: 0.6353869438171387 | KLD loss val: 38.33700434366862
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5280, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4986, device='cuda:0') 64 tensor(0.8470, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 68 | Age loss: 0.8582305444611443 |Age reg: 3.9110343721177845 | MSE loss: 854.0901353624132 | R2: 0.6474068429734972 | KLD loss: 38.24189927842882
# Epoch 68 | Age loss val: 0.9017073512077332 | MSE loss val: 970.0394490559896 | R2 val: 0.6150995890299479 | KLD loss val: 37.99132410685221
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6632, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1413, device='cuda:0') 64 tensor(0.8590, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 69 | Age loss: 0.8519404000706143 |Age reg: 3.8964535925123425 | MSE loss: 803.7038913302952 | R2: 0.6710698935720656 | KLD loss: 37.932921939425995
# Epoch 69 | Age loss val: 0.8990291754404703 | MSE loss val: 943.5526936848959 | R2 val: 0.6252023180325826 | KLD loss val: 38.27897262573242
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6841, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5153, device='cuda:0') 64 tensor(0.8445, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 70 | Age loss: 0.8491256501939561 |Age reg: 3.881936126285129 | MSE loss: 822.6773613823784 | R2: 0.6668762101067437 | KLD loss: 38.33665339152018
# Epoch 70 | Age loss val: 0.8931411107381185 | MSE loss val: 909.6365763346354 | R2 val: 0.6295019586881002 | KLD loss val: 38.50340016682943
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.8672, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6815, device='cuda:0') 64 tensor(0.8628, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 71 | Age loss: 0.8455368081728617 |Age reg: 3.8674642509884305 | MSE loss: 792.5314059787327 | R2: 0.6729866200023227 | KLD loss: 38.12366061740451
# Epoch 71 | Age loss val: 0.8890131513277689 | MSE loss val: 942.7213541666666 | R2 val: 0.6199480493863424 | KLD loss val: 38.165771484375
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6564, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1579, device='cuda:0') 64 tensor(0.8573, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 72 | Age loss: 0.8488605817159017 |Age reg: 3.8529618316226535 | MSE loss: 780.5974188910591 | R2: 0.6895953085687425 | KLD loss: 37.95318815443251
# Epoch 72 | Age loss val: 0.8937506079673767 | MSE loss val: 1110.3326619466145 | R2 val: 0.5623634656270345 | KLD loss val: 37.514668782552086
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.7912, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.5568, device='cuda:0') 64 tensor(0.8223, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 73 | Age loss: 0.8462425072987875 |Age reg: 3.8385470973120794 | MSE loss: 819.0473158094618 | R2: 0.6723378234439426 | KLD loss: 37.61416159735786
# Epoch 73 | Age loss val: 0.892139712969462 | MSE loss val: 1081.7286376953125 | R2 val: 0.5607497692108154 | KLD loss val: 37.542728424072266
# ...
# Epoch 177 | Age loss val: 0.7616751988728842 | MSE loss val: 526.7837422688802 | R2 val: 0.7855991323788961 | KLD loss val: 37.30302302042643
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6682, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2576, device='cuda:0') 64 tensor(0.7139, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 178 | Age loss: 0.7111199895540873 |Age reg: 2.58536434173584 | MSE loss: 471.3170810275608 | R2: 0.8116622037357755 | KLD loss: 37.42849477132162
# Epoch 178 | Age loss val: 0.7560893098513285 | MSE loss val: 564.5332845052084 | R2 val: 0.7645749847094218 | KLD loss val: 37.43097941080729
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.1601, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7147, device='cuda:0') 64 tensor(0.7158, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 179 | Age loss: 0.7050271564059787 |Age reg: 2.575808975431654 | MSE loss: 434.77142333984375 | R2: 0.8206006553437974 | KLD loss: 37.667122311062286
# Epoch 179 | Age loss val: 0.7570940256118774 | MSE loss val: 546.7149251302084 | R2 val: 0.782193919022878 | KLD loss val: 37.579053243001304
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5813, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2576, device='cuda:0') 64 tensor(0.7007, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 180 | Age loss: 0.7060967087745667 |Age reg: 2.5662704838646784 | MSE loss: 452.86597018771704 | R2: 0.8176069458325704 | KLD loss: 37.73037253485786
# Epoch 180 | Age loss val: 0.7544114788373312 | MSE loss val: 531.2036743164062 | R2 val: 0.7869370778401693 | KLD loss val: 37.648537953694664
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.1573, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3989, device='cuda:0') 64 tensor(0.7002, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 181 | Age loss: 0.7074784967634413 |Age reg: 2.5568266179826526 | MSE loss: 454.4612731933594 | R2: 0.816420488887363 | KLD loss: 37.69168217976888
# Epoch 181 | Age loss val: 0.7562341292699178 | MSE loss val: 558.8804117838541 | R2 val: 0.7831884423891703 | KLD loss val: 37.413167317708336
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6248, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1579, device='cuda:0') 64 tensor(0.7157, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 182 | Age loss: 0.7061116364267137 |Age reg: 2.547481960720486 | MSE loss: 462.1230299207899 | R2: 0.8153461482789781 | KLD loss: 37.585524241129555
# Epoch 182 | Age loss val: 0.754372219244639 | MSE loss val: 572.4660034179688 | R2 val: 0.7650592724482218 | KLD loss val: 37.81220245361328
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6159, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3075, device='cuda:0') 64 tensor(0.6967, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 183 | Age loss: 0.7072559462653266 |Age reg: 2.5382055971357556 | MSE loss: 471.69063991970484 | R2: 0.8088981840345595 | KLD loss: 37.59163623385959
# Epoch 183 | Age loss val: 0.759513239065806 | MSE loss val: 568.56005859375 | R2 val: 0.7757360339164734 | KLD loss val: 37.56870778401693
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.6011, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6565, device='cuda:0') 64 tensor(0.7189, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 184 | Age loss: 0.6998612350887723 |Age reg: 2.52876255247328 | MSE loss: 437.46579996744794 | R2: 0.8223234547509087 | KLD loss: 37.6336547003852
# Epoch 184 | Age loss val: 0.7489710648854574 | MSE loss val: 533.3334554036459 | R2 val: 0.7915521462758383 | KLD loss val: 37.45988972981771
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.7637, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4986, device='cuda:0') 64 tensor(0.7242, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 185 | Age loss: 0.700157019827101 |Age reg: 2.51945522096422 | MSE loss: 455.2478502061632 | R2: 0.8078943623436822 | KLD loss: 37.95610131157769
# Epoch 185 | Age loss val: 0.7475999593734741 | MSE loss val: 553.0017903645834 | R2 val: 0.7702333728472391 | KLD loss val: 37.953179677327476
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.6852, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6067, device='cuda:0') 64 tensor(0.7359, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 186 | Age loss: 0.7023399737146165 |Age reg: 2.5102100637223987 | MSE loss: 453.929443359375 | R2: 0.8125264644622803 | KLD loss: 38.06716834174262
# Epoch 186 | Age loss val: 0.7468201915423075 | MSE loss val: 531.5102742513021 | R2 val: 0.7798525889714559 | KLD loss val: 38.32366434733073
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5975, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4405, device='cuda:0') 64 tensor(0.6941, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 187 | Age loss: 0.6991265217463175 |Age reg: 2.501008086734348 | MSE loss: 452.6451110839844 | R2: 0.8142934044202169 | KLD loss: 38.121805826822914
# Epoch 187 | Age loss val: 0.7472380598386129 | MSE loss val: 548.3270263671875 | R2 val: 0.7671116590499878 | KLD loss val: 38.52571487426758
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.4841, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.7230, device='cuda:0') 64 tensor(0.6968, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 188 | Age loss: 0.702381796307034 |Age reg: 2.49176123407152 | MSE loss: 476.83668009440106 | R2: 0.8011011083920797 | KLD loss: 37.97181108262804
# Epoch 188 | Age loss val: 0.743841548760732 | MSE loss val: 553.930419921875 | R2 val: 0.7741180857022604 | KLD loss val: 38.22468185424805
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(1.4029, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6565, device='cuda:0') 64 tensor(0.6979, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 189 | Age loss: 0.6958383719126383 |Age reg: 2.4826314979129367 | MSE loss: 437.2933824327257 | R2: 0.8254013127750821 | KLD loss: 37.95071029663086
# Epoch 189 | Age loss val: 0.7424241503079733 | MSE loss val: 537.7771809895834 | R2 val: 0.7870385845502218 | KLD loss val: 37.82314936319987
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6289, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3490, device='cuda:0') 64 tensor(0.7031, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 190 | Age loss: 0.6957353817092048 |Age reg: 2.4734617604149713 | MSE loss: 449.886962890625 | R2: 0.8180507752630446 | KLD loss: 37.995176527235245
# Epoch 190 | Age loss val: 0.7386727333068848 | MSE loss val: 534.3328450520834 | R2 val: 0.7815586725870768 | KLD loss val: 38.350860595703125
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.5362, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6898, device='cuda:0') 64 tensor(0.7083, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 191 | Age loss: 0.6943783362706503 |Age reg: 2.464306910832723 | MSE loss: 440.48913235134546 | R2: 0.8200475441084968 | KLD loss: 37.99314837985568
# Epoch 191 | Age loss val: 0.7420774896939596 | MSE loss val: 528.2299499511719 | R2 val: 0.7790947755177816 | KLD loss val: 38.47830454508463
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5299, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1413, device='cuda:0') 64 tensor(0.7107, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 192 | Age loss: 0.6968538959821066 |Age reg: 2.455195082558526 | MSE loss: 437.47270033094617 | R2: 0.8243125213517083 | KLD loss: 38.110733879937065
# Epoch 192 | Age loss val: 0.7405548095703125 | MSE loss val: 531.8869222005209 | R2 val: 0.778903603553772 | KLD loss val: 38.50489298502604
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.6340, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2078, device='cuda:0') 64 tensor(0.6777, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 193 | Age loss: 0.6912168992890252 |Age reg: 2.446122328440348 | MSE loss: 464.5071716308594 | R2: 0.8145577841334872 | KLD loss: 37.91254001193576
# Epoch 193 | Age loss val: 0.7363483111063639 | MSE loss val: 545.3580932617188 | R2 val: 0.7835520704587301 | KLD loss val: 37.86114756266276
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.6476, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.4903, device='cuda:0') 64 tensor(0.6895, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 194 | Age loss: 0.6896756887435913 |Age reg: 2.437008168962267 | MSE loss: 439.6235588921441 | R2: 0.8165791299608018 | KLD loss: 38.160434299045136
# Epoch 194 | Age loss val: 0.7402174671490988 | MSE loss val: 539.5452880859375 | R2 val: 0.7814476490020752 | KLD loss val: 38.29417419433594
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.2338, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.3989, device='cuda:0') 64 tensor(0.7195, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 195 | Age loss: 0.6879263586468167 |Age reg: 2.4278992811838784 | MSE loss: 448.3770243326823 | R2: 0.8127432796690199 | KLD loss: 38.21468649970161
# Epoch 195 | Age loss val: 0.7348063190778097 | MSE loss val: 559.6253255208334 | R2 val: 0.7672404050827026 | KLD loss val: 37.96072769165039
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.4058, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6565, device='cuda:0') 64 tensor(0.6977, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 196 | Age loss: 0.6851812203725179 |Age reg: 2.4188687006632485 | MSE loss: 449.1404554578993 | R2: 0.8113196690877279 | KLD loss: 38.2338489956326
# Epoch 196 | Age loss val: 0.7295428117116293 | MSE loss val: 534.7698465983073 | R2 val: 0.7729914983113607 | KLD loss val: 38.4745979309082
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.8016, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6233, device='cuda:0') 64 tensor(0.6805, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 197 | Age loss: 0.6855118142233955 |Age reg: 2.4099607467651367 | MSE loss: 433.25465223524304 | R2: 0.822957456111908 | KLD loss: 38.071532779269745
# Epoch 197 | Age loss val: 0.731532871723175 | MSE loss val: 557.7366027832031 | R2 val: 0.7587498625119528 | KLD loss val: 38.89701588948568
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5608, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.1662, device='cuda:0') 64 tensor(0.6947, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 198 | Age loss: 0.6847468879487779 |Age reg: 2.4009587499830456 | MSE loss: 428.0314229329427 | R2: 0.8309368424945407 | KLD loss: 37.77912309434679
# Epoch 198 | Age loss val: 0.7346269885698954 | MSE loss val: 522.8754679361979 | R2 val: 0.791198710600535 | KLD loss val: 37.58571243286133
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.7651, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6815, device='cuda:0') 64 tensor(0.7274, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 199 | Age loss: 0.6836969786220126 |Age reg: 2.3918647236294217 | MSE loss: 434.0736558702257 | R2: 0.828056726190779 | KLD loss: 37.75616158379449
# Epoch 199 | Age loss val: 0.7394611438115438 | MSE loss val: 569.4225260416666 | R2 val: 0.7638354301452637 | KLD loss val: 38.307482401529946
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(-0.5693, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.2742, device='cuda:0') 64 tensor(0.6928, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 200 | Age loss: 0.6833745241165161 |Age reg: 2.3828651110331216 | MSE loss: 432.9337734646267 | R2: 0.8238059679667155 | KLD loss: 38.183417002360024
# Epoch 200 | Age loss val: 0.7327463626861572 | MSE loss val: 569.9089152018229 | R2 val: 0.7540028691291809 | KLD loss val: 38.92732238769531
# age_pred.shape, age.shape, batch.shape, x_rec.shape, x.shape torch.Size([64]) torch.Size([64]) torch.Size([64, 15812]) torch.Size([64, 15811]) torch.Size([64, 15811])
# age_pred[0], age[0], batch_size, age_loss tensor(0.6180, device='cuda:0', grad_fn=<SelectBackward0>) tensor(0.6482, device='cuda:0') 64 tensor(0.6612, device='cuda:0', grad_fn=<SqrtBackward0>)
# Epoch 201 | Age loss: 0.680727912320031 |Age reg: 2.3739320437113443 | MSE loss: 461.95704142252606 | R2: 0.8118390242258707 | KLD loss: 38.07701958550347
# Epoch 201 | Age loss val: 0.7225611408551534 | MSE loss val: 525.4562479654948 | R2 val: 0.7760588328043619 | KLD loss val: 38.376993815104164
